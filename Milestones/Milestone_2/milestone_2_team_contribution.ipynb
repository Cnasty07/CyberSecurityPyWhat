# %% [markdown]
# # Milestone 2 Contribution To pyWhat
#
# Right now it is pretty difficult to use if you are using a script as it is primarily ran through the CLI. We want to add an API wrapper and some other features that are TBD.

# %%
import pywhat
import subprocess

subprocess.run(["pywhat", "0x1f9090aaE28b8a3dCeaDf281B0F12828e676c326"])

# This is what we want to change to be able to use easier in programs.
# Out:
# Matched on: 0x1f9090aaE28b8a3dCeaDf281B0F12828e676c326
# Name: Ethereum (ETH) Wallet Address
# Link:  https://etherscan.io/address/0x1f9090aaE28b8a3dCeaDf281B0F12828e676c326
# CompletedProcess(args=['pywhat', '0x1f9090aaE28b8a3dCeaDf281B0F12828e676c326'], returncode=0)
